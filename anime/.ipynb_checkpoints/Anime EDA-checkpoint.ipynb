# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from wordcloud import WordCloud

# %% [markdown]
# ### This dataset is taken from website name gogoanime

# %%
df = pd.read_csv("animedata.csv")

# %%
df.head()
# Out:
#                    name        Type  \
# 0             A Channel   TV Series
# 1        A Channel Ova    TV Series
# 2    A Channel Special    TV Series
# 3       A Day Before Us         ONA
# 4  A Disguised Princess         ONA
#
#                                         Plot Summary  \
# 0   Toeru takes a test so she can enter the same ...
# 1   Toeru takes a test so she can enter the same ...
# 2   Toeru takes a test so she can enter the same ...
# 3   A Day Before Us is an animated Korean drama o...
# 4   "Ken always disguised herself as a man. She w...
#
#                                                Genre Released      Status  \
# 0              Comedy, School, Seinen, Slice of Life   2011.0   Completed
# 1              Comedy, School, Seinen, Slice of Life   2012.0   Completed
# 2              Comedy, School, Seinen, Slice of Life   2011.0   Completed
# 3                                            Romance   2018.0   Completed
# 4   Comedy, Drama, Fantasy, Gender Bender, Histor...   2021.0   Completed
#
#                                  Other name
# 0                                 A-Channel
# 1   A-Channel+smile, Aチャンネル+smile（プラス スマイル）
# 2                                 A-Channel
# 3             A Day Before Us (Season Zero)
# 4                                       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12240 entries, 0 to 12239
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          12240 non-null  object
#  1   Type          12229 non-null  object
#  2   Plot Summary  11736 non-null  object
#  3   Genre         12086 non-null  object
#  4   Released      12134 non-null  object
#  5   Status        12088 non-null  object
#  6   Other name    11480 non-null  object
# dtypes: object(7)
# memory usage: 669.5+ KB

# %% [markdown]
# ### This data has followling data about anime
# #### name of the anime
# #### Type of name anime (Type of anime mean is it TV show, or ova, or spring name etc)
# #### plot summary of anime
# #### Genre of Anime (Genre e.g comedy, romence, adventure, etc)
# ####  Status of anime mean this anime is completed or continue or upcoming
# #### Other name: In anime word anime has usually anime has one japanese name and other english name . E.G Attack on Titan other name Shingeki no Kyojin
# #### Released: year in which anime got released

# %%
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.show()

# %% [markdown]
# ## Anime are produce in japan so they original comes in japanese language so for USA anime comes in english dub so I am going to check the that

# %%
def contains_dub(s):
    return "dub" in s.lower()

# %%
mask = df['name'].apply(contains_dub)

# %%
print(df.loc[mask, 'name'])
# Out:
# 7                                   A Letter to Momo (Dub)
# 9                          A Little Snow Fairy Sugar (Dub)
# 12                                     A Starry Tale (Dub)
# 14                                   A Tree of Palme (Dub)
# 17                              A Wind Named Amnesia (Dub)
#                                ...
# 12215                     Yuukoku no Moriarty Part 2 (Dub)
# 12217                           Yuusei Shounen Papii (Dub)
# 12220                              Yuusha ga Shinda! (Dub)
# 12225    Yuusha Party wo Tsuihou sareta Beast Tamer, Sa...
# 12233                               Yuusha, Yamemasu (Dub)
# Name: name, Length: 2386, dtype: object

# %%
anime_in_dub = df[df['name'].str.contains('dub', case=False)]
anime_in_dub
# Out:
#                                                     name                Type  \
# 7                                 A Letter to Momo (Dub)               Movie
# 9                        A Little Snow Fairy Sugar (Dub)           TV Series
# 12                                   A Starry Tale (Dub)               Movie
# 14                                 A Tree of Palme (Dub)               Movie
# 17                            A Wind Named Amnesia (Dub)               Movie
# ...                                                  ...                 ...
# 12215                   Yuukoku no Moriarty Part 2 (Dub)           TV Series
# 12217                         Yuusei Shounen Papii (Dub)           TV Series
# 12220                            Yuusha ga Shinda! (Dub)   Spring 2023 Anime
# 12225  Yuusha Party wo Tsuihou sareta Beast Tamer, Sa...     Fall 2022 Anime
# 12233                             Yuusha, Yamemasu (Dub)   Spring 2022 Anime
#
#                                             Plot Summary  \
# 7       Momo is a young girl who grew up in a big cit...
# 9       Season Fairies create and control the weather...
# 12      Constellations were created thousands years a...
# 14      Palme is a puppet created by a man to care fo...
# 17      It happened quite suddenly, with no warning -...
# ...                                                  ...
# 12215   Great Britain is ablaze with news of a so-cal...
# 12217   Tells the story of a member of the Universal ...
# 12220   Far to the north of the world lies Hell's Gat...
# 12225   Beast Tamer Rein, who uses animals, was a mem...
# 12233   When Demon Queen Echidna begins her invasion ...
#
#                                                    Genre Released      Status  \
# 7                                                  Drama   2011.0   Completed
# 9                         Comedy, Fantasy, Music, Shoujo   2001.0   Completed
# 12                                               Fantasy   2011.0   Completed
# 14                    Adventure, Drama, Fantasy, Romance   2003.0   Completed
# 17               Action, Dementia, Drama, Sci-Fi, Seinen   1990.0   Completed
# ...                                                  ...      ...         ...
# 12215   Historical, Mystery, Psychological, Shounen, ...   2021.0   Completed
# 12217                 Action, Sci-Fi, Space, Super Power   1965.0   Completed
# 12220               Action, Comedy, Ecchi, Harem, Parody   2023.0     Ongoing
# 12225                                    Action, Fantasy   2022.0   Completed
# 12233                 Action, Adventure, Comedy, Fantasy   2022.0   Completed
#
#                                               Other name
# 7                               Momo e no Tegami, ももへの手紙
# 9       Chicchana Yukitsukai Sugar, Tiny Snow Fairy S...
# 12                                                   NaN
# 14                   Palme no Ki, Arbre de Palmem, パルムの樹
# 17      Kaze no Na wa Amnesia, Kaze no Namae wa Amune...
# ...                                                  ...
# 12215           Moriarty the Patriot Season 2, 憂国のモリアーティ
# 12217                             Prince Planet, 遊星少年パピイ
# 12220                         The Hero Is Dead!, 勇者が死んだ！
# 12225   Beast Tamer, 勇者パーティーを追放されたビーストテイマー、最強種の猫耳少女と出...
# 12233             I'm Quitting Heroing, Yuuyame, 勇者、辞めます
#
# [2386 rows x 7 columns]

# %%
anime_in_dub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2386 entries, 7 to 12233
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          2386 non-null   object
#  1   Type          2383 non-null   object
#  2   Plot Summary  2354 non-null   object
#  3   Genre         2373 non-null   object
#  4   Released      2373 non-null   object
#  5   Status        2373 non-null   object
#  6   Other name    2256 non-null   object
# dtypes: object(7)
# memory usage: 149.1+ KB

# %% [markdown]
# ## here we can see that there are 2386 anime are in dub it also mean that in this dataset this data duplicate so you need to remove this row for perfroming nlp

# %%
anime_in_sub = df[~df['name'].str.contains('dub', case=False)]
anime_in_sub
# Out:
#                        name        Type  \
# 0                 A Channel   TV Series
# 1            A Channel Ova    TV Series
# 2        A Channel Special    TV Series
# 3           A Day Before Us         ONA
# 4      A Disguised Princess         ONA
# ...                     ...         ...
# 12235      Yuusha, Yamemasu         OVA
# 12236              Yuushibu   TV Series
# 12237          Yuushibu OVA         OVA
# 12238             Yuyushiki   TV Series
# 12239             Yuyushiki         OVA
#
#                                             Plot Summary  \
# 0       Toeru takes a test so she can enter the same ...
# 1       Toeru takes a test so she can enter the same ...
# 2       Toeru takes a test so she can enter the same ...
# 3       A Day Before Us is an animated Korean drama o...
# 4       "Ken always disguised herself as a man. She w...
# ...                                                  ...
# 12235   A two-part new animation released with both B...
# 12236   Yuushibu Is The story revolves around Raul, a...
# 12237   Unaired episode that was released with volume...
# 12238   The manga follows the school life of three gi...
# 12239                                  Yuyushiki Special
#
#                                                    Genre Released      Status  \
# 0                  Comedy, School, Seinen, Slice of Life   2011.0   Completed
# 1                  Comedy, School, Seinen, Slice of Life   2012.0   Completed
# 2                  Comedy, School, Seinen, Slice of Life   2011.0   Completed
# 3                                                Romance   2018.0   Completed
# 4       Comedy, Drama, Fantasy, Gender Bender, Histor...   2021.0   Completed
# ...                                                  ...      ...         ...
# 12235                 Action, Adventure, Comedy, Fantasy   2022.0   Completed
# 12236                    Comedy, Ecchi, Fantasy, Romance   2013.0   Completed
# 12237                             Comedy, Ecchi, Fantasy   2014.0   Completed
# 12238              Comedy, School, Seinen, Slice of Life   2013.0   Completed
# 12239                                             Comedy   2017.0   Completed
#
#                                               Other name
# 0                                              A-Channel
# 1                A-Channel+smile, Aチャンネル+smile（プラス スマイル）
# 2                                              A-Channel
# 3                          A Day Before Us (Season Zero)
# 4                                                    NaN
# ...                                                  ...
# 12235                               I'm Quitting Heroing
# 12236   Yuusha ni Narenakatta Ore wa Shibushibu Shuus...
# 12237                    Yusibu OVA, Yu-sibu OVA, Yusibu
# 12238                                                ゆゆ式
# 12239                              ゆゆ式 OVA『困らせたり、困らされたり』
#
# [9854 rows x 7 columns]

# %% [markdown]
# ### In this dataset there are anime which has more than one season so I am deleting by using drop plot summay
# if some anime has same plot summary mean they are some anime diffent season

# %%
anime_in_sub = anime_in_sub.drop_duplicates(subset=['Plot Summary'])
anime_in_sub
# Out:
#                                 name                Type  \
# 0                          A Channel           TV Series
# 3                    A Day Before Us                 ONA
# 4               A Disguised Princess                 ONA
# 5      A Favorite Marriage is Coming                 ONA
# 6          A Game Between You and Me                 ONA
# ...                              ...                 ...
# 12232               Yuusha, Yamemasu   Spring 2022 Anime
# 12234               Yuusha, Yamemasu             Special
# 12236                       Yuushibu           TV Series
# 12238                      Yuyushiki           TV Series
# 12239                      Yuyushiki                 OVA
#
#                                             Plot Summary  \
# 0       Toeru takes a test so she can enter the same ...
# 3       A Day Before Us is an animated Korean drama o...
# 4       "Ken always disguised herself as a man. She w...
# 5                                                    NaN
# 6       After being cheated on by her boyfriend, Estr...
# ...                                                  ...
# 12232   After saving the world, the strongest hero Le...
# 12234   A two-part new animation released with both B...
# 12236   Yuushibu Is The story revolves around Raul, a...
# 12238   The manga follows the school life of three gi...
# 12239                                  Yuyushiki Special
#
#                                                    Genre Released      Status  \
# 0                  Comedy, School, Seinen, Slice of Life   2011.0   Completed
# 3                                                Romance   2018.0   Completed
# 4       Comedy, Drama, Fantasy, Gender Bender, Histor...   2021.0   Completed
# 5                                                Romance   2019.0   Completed
# 6                             Adventure, Comedy, Romance   2021.0   Completed
# ...                                                  ...      ...         ...
# 12232                 Action, Adventure, Comedy, Fantasy   2022.0   Completed
# 12234                 Action, Adventure, Comedy, Fantasy   2022.0   Completed
# 12236                    Comedy, Ecchi, Fantasy, Romance   2013.0   Completed
# 12238              Comedy, School, Seinen, Slice of Life   2013.0   Completed
# 12239                                             Comedy   2017.0   Completed
#
#                                               Other name
# 0                                              A-Channel
# 3                          A Day Before Us (Season Zero)
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# ...                                                  ...
# 12232                      I'm Quitting Heroing, 勇者、辞めます
# 12234   Kenshū Ryokō wa Mokuteki o Miushinau na; 研修旅行...
# 12236   Yuusha ni Narenakatta Ore wa Shibushibu Shuus...
# 12238                                                ゆゆ式
# 12239                              ゆゆ式 OVA『困らせたり、困らされたり』
#
# [8286 rows x 7 columns]

# %%
anime_in_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8286 entries, 0 to 12239
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          8286 non-null   object
#  1   Type          8285 non-null   object
#  2   Plot Summary  8285 non-null   object
#  3   Genre         8224 non-null   object
#  4   Released      8247 non-null   object
#  5   Status        8228 non-null   object
#  6   Other name    7878 non-null   object
# dtypes: object(7)
# memory usage: 517.9+ KB

# %%
anime_in_sub.describe()
# Out:
#              name        Type  \
# count        8286        8285
# unique       6877          64
# top     Lupin III   TV Series
# freq           46        2733
#
#                                              Plot Summary    Genre Released  \
# count                                                8285     8224     8247
# unique                                               8285     3029      212
# top      Toeru takes a test so she can enter the same ...   Comedy     2021
# freq                                                    1      207      192
#
#             Status  Other name
# count         8228        7878
# unique           3        7161
# top      Completed   Lupin III
# freq          7672          29

# %% [markdown]
# # let's check In which year more anime got released

# %%
released = anime_in_sub["Released"]

# convert the "Released" column to a datetime format
released = pd.to_datetime(released, errors='coerce')

# extract the year from the datetime format and store it in a new column
anime_in_sub["year"] = released.dt.year
# Out:
# /tmp/ipykernel_5981/2518784324.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime_in_sub["year"] = released.dt.year

# %%
anime_per_year = anime_in_sub.groupby("year")["name"].count()
plt.bar(anime_per_year.index, anime_per_year.values)
plt.xlabel("Year")
plt.ylabel("Number of Anime Released")
plt.title("Anime Released Per Year")
plt.xlim(1960, 2025)
plt.show()

# %% [markdown]
# ### we can see that in recent year more anime got released
# #### If you are anime fan you know nows days we have alot of anime content

# %% [markdown]
# # Here I am going to plot status and wants to check how much anime are comleted

# %%
# group the data by "Status" column and count the number of animes in each group
status_counts = anime_in_sub.groupby('Status').size()

# create a bar chart of the status counts
plt.bar(status_counts.index, status_counts.values)

# set the chart title and axis labels
plt.title('Anime Status')
plt.xlabel('Status')
plt.ylabel('Count')

# display the chart
plt.show()

# %%
# for num in range(len(anime_in_sub['Genre'])):
genre = []
list_of_genre = anime_in_sub['Genre'].tolist()
for num in range(len(list_of_genre)):
    a = str(list_of_genre[num]).split(",")
#     print(list_of_genre)
# print(a)
    for x in range(len(a)):
        genre.append(a[x])

print(genre)
# Out:
# [' Comedy', ' School', ' Seinen', ' Slice of Life', ' Romance', ' Comedy', ' Drama', ' Fantasy', ' Gender Bender', ' Historical', ' Shoujo', ' Romance', ' Adventure', ' Comedy', ' Romance', ' Comedy', ' Fantasy', ' Action', ' Adventure', ' Comedy', ' Ecchi', ' Harem', ' Martial Arts', ' Shounen', ' Comedy', ' Drama', ' Action', ' Dementia', ' Drama', ' Sci-Fi', ' Comedy', ' School', ' Seinen', ' Slice of Life', ' Music', ' Romance', ' School', ' Shoujo', ' Action', ' Mecha', ' Sci-Fi', ' Action', ' Sci-Fi', ' Action', ' Sci-Fi', ' Sci-Fi', ' Drama', ' Slice of Life', ' Martial Arts', ' Seinen', ' Sports', ' Comedy', ' Magic', ' Romance', ' Seinen', ' Supernatural', ' Comedy', ' Harem', ' Romance', ' Seinen', ' Supernatural', ' Comedy', ' Magic', ' Supernatural', ' Action', ' Comedy', ' Seinen', ' Sports', ' Comedy', ' Romance', ' Comedy', ' Ecchi', ' Fantasy', ' Parody', ' Action', ' Ecchi', ' Harem', ' Romance', ' School', ' Supernatural', ' Action', ' Comedy', ' Ecchi', ' Drama', ' Police', ' Drama', ' Fantasy', ' Mystery', ' Police', ' Seinen', ' Drama', ' Fantasy', ' Police', ' Seinen', ' Action', ' Romance', ' School', ' Sci-Fi', ' Shounen', ' Action', ' Game', ' Romance', ' School', ' Sci-Fi', ' Comedy', ' Romance', ' School', ' Slice of Life', ' Comedy', ' Drama', ' Romance', ' School', ' Shoujo', ' Sports', ' Drama', ' Romance', ' School', ' Shoujo', ' Sports', ' Drama', ' Shoujo', ' Action', ' Drama', ' Sports', ' Comedy', ' Comedy', ' School', ' Slice of Life', ' Mecha', ' Police', ' Sci-Fi', ' Music', ' School', ' Adventure', ' Dementia', ' Mecha', ' Mystery', ' Police', ' Psychological', ' Sci-Fi', ' Thriller', ' Romance', ' School', ' Shoujo Ai', ' Slice of Life', ' Comedy', ' Action', ' Romance', ' Comedy', ' Slice of Life', ' Action', ' Samurai', ' Action', ' Samurai', ' Comedy', ' Kids', ' School', ' Martial Arts', ' Super Power', ' Historical', ' Mystery', ' Action', ' Adventure', ' Romance', ' Sci-Fi', ' Action', ' Adventure', ' Comedy', ' Ecchi', ' Sci-Fi', ' Comedy', ' Music', ' Comedy', ' Slice of Life', ' Comedy', ' Slice of Life', ' Comedy', ' Slice of Life', ' Comedy', ' Slice of Life', ' Comedy', ' Comedy', ' Slice of Life', ' Action', ' Drama', ' Supernatural', ' Action', ' Adventure', ' Comedy', ' Ecchi', ' Sci-Fi', ' Comedy', ' Magic', ' Romance', ' Supernatural', ' Comedy', ' Magic', ' Romance', ' Supernatural', ' Comedy', ' Magic', ' Romance', ' Supernatural', ' Comedy', ' School', ' Shounen', ' Drama', ' School', ' Shounen', ' Sports', ' Comedy', ' Romance', ' School', ' Action', ' Sci-Fi', ' Super Power', ' Comedy', ' Slice of Life', ' Comedy', ' Slice of Life', ' Comedy', ' Slice of Life', ' Slice of Life', ' Comedy', ' Sci-Fi', ' Drama', ' Romance', ' Drama', ' Historical', ' School', ' Slice of Life', ' Drama', ' Sci-Fi', ' Suspense', ' Boys Love', ' Drama', ' Erotica', ' Sci-Fi', ' Action', ' Drama', ' Romance', ' Sci-Fi', ' Yaoi', ' Drama', ' Music', ' School', ' Sci-Fi', ' Drama', ' Historical', ' Slice of Life', ' Comedy', ' Comedy', ' Romance', ' Shoujo', ' Drama', ' Historical', ' Slice of Life', ' Comedy', ' Sci-Fi', ' Shounen', ' Comedy', ' Ecchi', ' Romance', ' School', ' Seinen', ' Adventure', ' Comedy', ' Kids', ' Shounen', ' Music', ' Music', ' Music', ' Shoujo', ' Action', ' Military', ' Mystery', ' Police', ' Sci-Fi', ' Supernatural', ' Thriller', ' Action', ' Mystery', ' Police', ' Psychological', ' Supernatural', ' Thriller', ' Drama', ' Romance', ' Seinen', ' Adventure', ' Mecha', ' Sci-Fi', ' Shounen', ' Action', ' Adventure', ' Shounen', ' Comedy', ' Magic', ' Shoujo', ' Comedy', ' Magic', ' Shoujo', ' Adventure', ' Sci-Fi', ' Shounen', ' Supernatural', ' Action', ' Adventure', ' Mystery', ' Sci-Fi', ' Shounen', ' Supernatural', ' Action', ' Mecha', ' Sci-Fi', ' Ecchi', ' Harem', ' Seinen', ' Romance', ' School', ' Shounen', ' Sports', ' Romance', ' School', ' Shounen', ' Sports', ' Comedy', ' School', ' Seinen', ' Thriller', ' Action', ' Comedy', ' Historical', ' Seinen',  ...

# %%
genre = [x for x in genre if x != 'nan']
# print(my_list)  # ['apple', 'cherry', 'date']
for num in range(len(genre)):
    if genre[num] == "nan":
        print(num)

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# assume you have a list of genres
# genres = ['Action', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Mystery', 'Sci-Fi', 'Thriller']

# create a string with all the genres separated by a space
genres_text = ' '.join(genre)

# create the WordCloud object
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(genres_text)

# plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
  
plt.show()

# %%
genre
# Out:
# [' Comedy',
#  ' School',
#  ' Seinen',
#  ' Slice of Life',
#  ' Romance',
#  ' Comedy',
#  ' Drama',
#  ' Fantasy',
#  ' Gender Bender',
#  ' Historical',
#  ' Shoujo',
#  ' Romance',
#  ' Adventure',
#  ' Comedy',
#  ' Romance',
#  ' Comedy',
#  ' Fantasy',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Ecchi',
#  ' Harem',
#  ' Martial Arts',
#  ' Shounen',
#  ' Comedy',
#  ' Drama',
#  ' Action',
#  ' Dementia',
#  ' Drama',
#  ' Sci-Fi',
#  ' Comedy',
#  ' School',
#  ' Seinen',
#  ' Slice of Life',
#  ' Music',
#  ' Romance',
#  ' School',
#  ' Shoujo',
#  ' Action',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Action',
#  ' Sci-Fi',
#  ' Action',
#  ' Sci-Fi',
#  ' Sci-Fi',
#  ' Drama',
#  ' Slice of Life',
#  ' Martial Arts',
#  ' Seinen',
#  ' Sports',
#  ' Comedy',
#  ' Magic',
#  ' Romance',
#  ' Seinen',
#  ' Supernatural',
#  ' Comedy',
#  ' Harem',
#  ' Romance',
#  ' Seinen',
#  ' Supernatural',
#  ' Comedy',
#  ' Magic',
#  ' Supernatural',
#  ' Action',
#  ' Comedy',
#  ' Seinen',
#  ' Sports',
#  ' Comedy',
#  ' Romance',
#  ' Comedy',
#  ' Ecchi',
#  ' Fantasy',
#  ' Parody',
#  ' Action',
#  ' Ecchi',
#  ' Harem',
#  ' Romance',
#  ' School',
#  ' Supernatural',
#  ' Action',
#  ' Comedy',
#  ' Ecchi',
#  ' Drama',
#  ' Police',
#  ' Drama',
#  ' Fantasy',
#  ' Mystery',
#  ' Police',
#  ' Seinen',
#  ' Drama',
#  ' Fantasy',
#  ' Police',
#  ' Seinen',
#  ' Action',
#  ' Romance',
#  ' School',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Romance',
#  ' School',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Romance',
#  ' School',
#  ' Slice of Life',
#  ' Comedy',
#  ' Drama',
#  ' Romance',
#  ' School',
#  ' Shoujo',
#  ' Sports',
#  ' Drama',
#  ' Romance',
#  ' School',
#  ' Shoujo',
#  ' Sports',
#  ' Drama',
#  ' Shoujo',
#  ' Action',
#  ' Drama',
#  ' Sports',
#  ' Comedy',
#  ' Comedy',
#  ' School',
#  ' Slice of Life',
#  ' Mecha',
#  ' Police',
#  ' Sci-Fi',
#  ' Music',
#  ' School',
#  ' Adventure',
#  ' Dementia',
#  ' Mecha',
#  ' Mystery',
#  ' Police',
#  ' Psychological',
#  ' Sci-Fi',
#  ' Thriller',
#  ' Romance',
#  ' School',
#  ' Shoujo Ai',
#  ' Slice of Life',
#  ' Comedy',
#  ' Action',
#  ' Romance',
#  ' Comedy',
#  ' Slice of Life',
#  ' Action',
#  ' Samurai',
#  ' Action',
#  ' Samurai',
#  ' Comedy',
#  ' Kids',
#  ' School',
#  ' Martial Arts',
#  ' Super Power',
#  ' Historical',
#  ' Mystery',
#  ' Action',
#  ' Adventure',
#  ' Romance',
#  ' Sci-Fi',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Ecchi',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Music',
#  ' Comedy',
#  ' Slice of Life',
#  ' Comedy',
#  ' Slice of Life',
#  ' Comedy',
#  ' Slice of Life',
#  ' Comedy',
#  ' Slice of Life',
#  ' Comedy',
#  ' Comedy',
#  ' Slice of Life',
#  ' Action',
#  ' Drama',
#  ' Supernatural',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Ecchi',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Magic',
#  ' Romance',
#  ' Supernatural',
#  ' Comedy',
#  ' Magic',
#  ' Romance',
#  ' Supernatural',
#  ' Comedy',
#  ' Magic',
#  ' Romance',
#  ' Supernatural',
#  ' Comedy',
#  ' School',
#  ' Shounen',
#  ' Drama',
#  ' School',
#  ' Shounen',
#  ' Sports',
#  ' Comedy',
#  ' Romance',
#  ' School',
#  ' Action',
#  ' Sci-Fi',
#  ' Super Power',
#  ' Comedy',
#  ' Slice of Life',
#  ' Comedy',
#  ' Slice of Life',
#  ' Comedy',
#  ' Slice of Life',
#  ' Slice of Life',
#  ' Comedy',
#  ' Sci-Fi',
#  ' Drama',
#  ' Romance',
#  ' Drama',
#  ' Historical',
#  ' School',
#  ' Slice of Life',
#  ' Drama',
#  ' Sci-Fi',
#  ' Suspense',
#  ' Boys Love',
#  ' Drama',
#  ' Erotica',
#  ' Sci-Fi',
#  ' Action',
#  ' Drama',
#  ' Romance',
#  ' Sci-Fi',
#  ' Yaoi',
#  ' Drama',
#  ' Music',
#  ' School',
#  ' Sci-Fi',
#  ' Drama',
#  ' Historical',
#  ' Slice of Life',
#  ' Comedy',
#  ' Comedy',
#  ' Romance',
#  ' Shoujo',
#  ' Drama',
#  ' Historical',
#  ' Slice of Life',
#  ' Comedy',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Comedy',
#  ' Ecchi',
#  ' Romance',
#  ' School',
#  ' Seinen',
#  ' Adventure',
#  ' Comedy',
#  ' Kids',
#  ' Shounen',
#  ' Music',
#  ' Music',
#  ' Music',
#  ' Shoujo',
#  ' Action',
#  ' Military',
#  ' Mystery',
#  ' Police',
#  ' Sci-Fi',
#  ' Supernatural',
#  ' Thriller',
#  ' Action',
#  ' Mystery',
#  ' Police',
#  ' Psychological',
#  ' Supernatural',
#  ' Thriller',
#  ' Drama',
#  ' Romance',
#  ' Seinen',
#  ' Adventure',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Shounen',
#  ' Comedy',
#  ' Magic',
#  ' Shoujo',
#  ' Comedy',
#  ' Magic',
#  ' Shoujo',
#  ' Adventure',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Supernatural',
#  ' Action',
#  ' Adventure',
#  ' Mystery',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Supernatural',
#  ' Action',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Ecchi',
#  ' Harem',
#  ' Seinen',
#  ' Romance',
#  ' School',
#  ' Shounen',
#  ' Sports',
#  ' Romance',
#  ' School',
#  ' Shounen',
#  ' Sports',
#  ' Comedy',
#  ' School',
#  ' Seinen',
#  ' Thriller',
#  ' Action',
#  ' Comedy',
#  ' Historical',
#  ' Seinen',
#  ' Supernatural',
#  ' Action',
#  ' Fantasy',
#  ' Mecha',
#  ' Comedy',
#  ' Ecchi',
#  ' Seinen',
#  ' Comedy',
#  ' Ecchi',
#  ' Seinen',
#  ' Action',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Romance',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Romance',
#  ' Action',
#  ' Comedy',
#  ' Seinen',
#  ' Comedy',
#  ' Ecchi',
#  ' Fantasy',
#  ' Romance',
#  ' Action',
#  ' Romance',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Comedy',
#  ' Comedy',
#  ' Fantasy',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Martial Arts',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Historical',
#  ' Martial Arts',
#  ' Slice of Life',
#  ' Action',
#  ' Adventure',
#  ' Adventure',
#  ' Demons',
#  ' Drama',
#  ' Fantasy',
#  ' Historical',
#  ' Martial Arts',
#  ' Romance',
#  ' Adventure',
#  ' Fantasy',
#  ' Historical',
#  ' Mystery',
#  ' Supernatural',
#  ' Adventure',
#  ' Fantasy',
#  ' Historical',
#  ' Mystery',
#  ' Supernatural',
#  ' Comedy',
#  ' Romance',
#  ' School',
#  ' Super Power',
#  ' Comedy',
#  ' Romance',
#  ' School',
#  ' Super Power',
#  ' Completed',
#  ' Comedy',
#  ' School',
#  ' Super Power',
#  ' Comedy',
#  ' Romance',
#  ' Action',
#  ' Demons',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Adventure',
#  ' Supernatural',
#  ' Mystery',
#  ' Romance',
#  ' Supernatural',
#  ' Vampire',
#  ' Action',
#  ' Martial Arts',
#  ' Shounen',
#  ' Action',
#  ' Martial Arts',
#  ' Shounen',
#  ' Action',
#  ' Martial Arts',
#  ' Shounen',
#  ' Action',
#  ' Shounen',
#  ' Sports',
#  ' Action',
#  ' Comedy',
#  ' School',
#  ' Shounen',
#  ' Supernatural',
#  ' Action',
#  ' Fantasy',
#  ' Game',
#  ' Adventure',
#  ' Fantasy',
#  ' Strategy Game',
#  ' Action',
#  ' Fantasy',
#  ' Game',
#  ' Action',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Fantasy',
#  ' Game',
#  ' Action',
#  ' Fantasy',
#  ' Game',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Adventure',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Adventure',
#  ' Game',
#  ' Comedy',
#  ' Romance',
#  ' School',
#  ' Shounen',
#  ' Action',
#  ' Historical',
#  ' Samurai',
#  ' Fantasy',
#  ' Historical',
#  ' Action',
#  ' Drama',
#  ' Historical',
#  ' Samurai',
#  ' Historical',
#  ' Action',
#  ' Comedy',
#  ' Historical',
#  ' Music',
#  ' Shoujo',
#  ' Action',
#  ' Historical',
#  ' Samurai',
#  ' Seinen',
#  ' Slice of Life',
#  ' Cars',
#  ' Seinen',
#  ' Slice of Life',
#  ' Sports',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Ecchi',
#  ' Fantasy',
#  ' Harem',
#  ' Magic',
#  ' Shounen',
#  ' Super Power',
#  ' Adventure',
#  ' Cars',
#  ' Shounen',
#  ' Sports',
#  ' Cars',
#  ' Shounen',
#  ' Sports',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Sports',
#  ' Sports',
#  ' Sports',
#  ' Adventure',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Action',
#  ' Drama',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Drama',
#  ' Romance',
#  ' School',
#  ' Shounen',
#  ' Sports',
#  ' Comedy',
#  ' School',
#  ' Sports',
#  ' Action',
#  ' Adventure',
#  ' Drama',
#  ' Shoujo',
#  ' Comedy',
#  ' Comedy',
#  ' Kids',
#  ' Slice of Life',
#  ' Comedy',
#  ' Kids',
#  ' Slice of Life',
#  ' Music',
#  ' Action',
#  ' Mystery',
#  ' Super Power',
#  ' Thriller',
#  ' Horror',
#  ' Action',
#  ' Mystery',
#  ' Super Power',
#  ' Thriller',
#  ' Action',
#  ' Comedy',
#  ' Ecchi',
#  ' School',
#  ' Shounen',
#  ' Supernatural',
#  ' Action',
#  ' Comedy',
#  ' Ecchi',
#  ' School',
#  ' Shounen',
#  ' Supernatural',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Action',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Horror',
#  ' Romance',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Ecchi',
#  ' Fantasy',
#  ' Harem',
#  ' Magic',
#  ' Romance',
#  ' Action',
#  ' Seinen',
#  ' Fantasy',
#  ' Music',
#  ' Romance',
#  ' School',
#  ' Action',
#  ' Mecha',
#  ' Military',
#  ' Sci-Fi',
#  ' Space',
#  ' Action',
#  ' Mecha',
#  ' Military',
#  ' Sci-Fi',
#  ' Space',
#  ' Romance',
#  ' School',
#  ' Shounen Ai',
#  ' Drama',
#  ' Shoujo',
#  ' Slice of Life',
#  ' Comedy',
#  ' Fantasy',
#  ' Historical',
#  ' Romance',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Comedy',
#  ' Drama',
#  ' Romance',
#  ' Slice of Life',
#  ' Action',
#  ' Game',
#  ' Kids',
#  ' Action',
#  ' Game',
#  ' Kids',
#  ' Cars',
#  ' Shounen',
#  ' Sports',
#  ' Adventure',
#  ' Comedy',
#  ' Fantasy',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Action',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Action',
#  ' Adventure',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Action',
#  ' Drama',
#  ' Sci-Fi',
#  ' Space',
#  ' Action',
#  ' Shounen',
#  ' Sports',
#  ' Action',
#  ' Shounen',
#  ' Sports',
#  ' Action',
#  ' Shounen',
#  ' Sports',
#  ' Action',
#  ' Shounen',
#  ' Sports',
#  ' Action',
#  ' Shounen',
#  ' Sports',
#  ' Action',
#  ' Shounen',
#  ' Sports',
#  ' Comedy',
#  ' Drama',
#  ' Fantasy',
#  ' Romance',
#  ' Shoujo',
#  ' Adventure',
#  ' Fantasy',
#  ' Game',
#  ' Shounen',
#  ' Adventure',
#  ' Comedy',
#  ' Drama',
#  ' Romance',
#  ' School',
#  ' Shoujo',
#  ' Adventure',
#  ' Comedy',
#  ' Fantasy',
#  ' Magic',
#  ' Romance',
#  ' Shoujo',
#  ' Adventure',
#  ' Comedy',
#  ' Fantasy',
#  ' Magic',
#  ' Romance',
#  ' Shoujo',
#  ' Adventure',
#  ' Comedy',
#  ' Fantasy',
#  ' Magic',
#  ' Romance',
#  ' Shoujo',
#  ' Fantasy',
#  ' Romance',
#  ' Shoujo',
#  ' Comedy',
#  ' Fantasy',
#  ' Magic',
#  ' Shoujo',
#  ' Adventure',
#  ' Comedy',
#  ' Drama',
#  ' Magic',
#  ' Romance',
#  ' School',
#  ' Action',
#  ' Adventure',
#  ' Demons',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Demons',
#  ' Game',
#  ' Action',
#  ' Adventure',
#  ' Demons',
#  ' Game',
#  ' Shounen',
#  ' Action',
#  ' Game',
#  ' Comedy',
#  ' Game',
#  ' Comedy',
#  ' Game',
#  ' Strategy Game',
#  ' Comedy',
#  ' Action',
#  ' Game',
#  ' Shounen',
#  ' Comedy',
#  ' Parody',
#  ' Supernatural',
#  ' Comedy',
#  ' Supernatural',
#  ' Comedy',
#  ' Parody',
#  ' Drama',
#  ' Music',
#  ' Romance',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Adventure',
#  ' Comedy',
#  ' Historical',
#  ' Martial Arts',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Sci-Fi',
#  ' Adventure',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Supernatural',
#  ' Action',
#  ' Mystery',
#  ' Vampire',
#  ' Action',
#  ' Supernatural',
#  ' Vampire',
#  ' Action',
#  ' Supernatural',
#  ' Vampire',
#  ' Action',
#  ' Fantasy',
#  ' Military',
#  ' Action',
#  ' Fantasy',
#  ' Military',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Mystery',
#  ' Romance',
#  ' Comedy',
#  ' Romance',
#  ' Comedy',
#  ' Fantasy',
#  ' Slice of Life',
#  ' Comedy',
#  ' Fantasy',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Fantasy',
#  ' Slice of Life',
#  ' Action',
#  ' Comedy',
#  ' Parody',
#  ' Comedy',
#  ' Fantasy',
#  ' Action',
#  ' Sci-Fi',
#  ' Action',
#  ' Sci-Fi',
#  ' Action',
#  ' Sci-Fi',
#  ' Comedy',
#  ' Fantasy',
#  ' Seinen',
#  ' Slice of Life',
#  ' Supernatural',
#  ' Action',
#  ' Romance',
#  ' Romance',
#  ' Action',
#  ' Drama',
#  ' Historical',
#  ' Seinen',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Magic',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Magic',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Action',
#  ' Adventure',
#  ' Demons',
#  ' Gore',
#  ' Shounen',
#  ' Comedy',
#  ' Ecchi',
#  ' School',
#  ' Seinen',
#  ' Drama',
#  ' Music',
#  ' Slice of Life',
#  ' Action',
#  ' Adventure',
#  ' Horror',
#  ' Mecha',
#  ' Psychological',
#  ' Sci-Fi',
#  ' Shounen',
#  ' Action',
#  ' Adventure',
#  ' Action',
#  ' Mecha',
#  ' Military',
#  ' Mystery',
#  ' Space',
#  ' Supernatural',
#  ' Adventure',
#  ' Action',
#  ' Adventure',
#  ' Drama',
#  ' Fantasy',
#  ' Magic',
#  ' Mecha',
#  ' Sci-Fi',
#  ' Comedy',
#  ' School',
#  ' Seinen',
#  ' Comedy',
#  ' Comedy',
#  ' Drama',
#  ' Harem',
#  ' Romance',
#  ' Supernatural',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Demons',
#  ' Shounen',
#  ' Super Power',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Demons',
#  ' Shounen',
#  ' Supernatural',
#  ' Action',
#  ' Comedy',
#  ' Fantasy',
#  ' Magic',
#  ' Romance',
#  ' School',
#  ' Shoujo',
#  ' Comedy',
#  ' Strategy Game',
#  ' Music',
#  ' Comedy',
#  ' Music',
#  ' Music',
#  ' Drama',
#  ' Harem',
#  ' Magic',
#  ' Romance',
#  ' Drama',
#  ' Harem',
#  ' Magic',
#  ' Romance',
#  ' Drama',
#  ' Ecchi',
#  ' Romance',
#  ' School',
#  ' Comedy',
#  ' Drama',
#  ' Fantasy',
#  ' Harem',
#  ' Romance',
#  ' Drama',
#  ' Ecchi',
#  ' Romance',
#  ' School',
#  ' Comedy',
#  ' Drama',
#  ' Harem',
#  ' Romance',
#  ' Supernatural',
#  ' Comedy',
#  ' Action',
#  ' Comedy',
#  ' Mystery',
#  ' Action',
#  ' Adventure',
#  ' Fantasy',
#  ' Comedy',
#  ' Demons',
#  ' Fantasy',
#  ' Magic',
#  ' School',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Fantasy',
#  ' Adventure',
#  ' Drama',
#  ' Romance',
#  ' Supernatural',
#  ' Action',
#  ' Adventure',
#  ' Comedy',
#  ' Drama',
#  ' Fantasy',
#  ' Martial Arts',
#  ' Romance',
#  ' Supernatural',
#  ' Comedy',
#  ' Sci-Fi',
#  ' Shoujo',
#  ' Adventure',
#  ' Comedy',
#  ' Historical',
#  ' Adventure',
#  ' Comedy',
#  ' Historical',
#  ' Comedy',
#  ' Shounen',
#  ' Comedy',
#  ' Shounen',
#  ' Slice of Life',
#  ' Action',
#  ' Action',
#  ' Fantasy',
#  ' Comedy',
#  ' Magic',
#  ...]

# %%
from collections import Counter
genre_series = pd.Series(genre)

# count frequency of each genre
genre_counts = genre_series.value_counts()

# sort in descending order
sorted_counts = genre_counts.sort_values(ascending=False)

# take top 10
top10_counts = sorted_counts.head(9)

# plot as bar chart
fig, ax = plt.subplots(figsize=(8, 6))
plt.bar(top10_counts.index, top10_counts.values)
plt.title('Top 10 Anime Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show(fig)

# %%
plt.bar(anime_per_year.index, anime_per_year.values)
# Out:
# <BarContainer object of 68 artists>

# %%
genre_series = pd.Series(genre)

# count frequency of each genre
genre_counts = genre_series.value_counts()

# sort in descending order
sorted_counts = genre_counts.sort_values(ascending=False)

# take top 10
top10_counts = sorted_counts.head(9)

# plot as bar chart
fig , ax= plt.subplots(figsize=(8, 6))
top10_counts.plot.bar(ax = ax)
# plt.title('Top 10 Anime Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
from collections import Counter
genre_series = pd.Series(genre)

# count frequency of each genre
genre_counts = genre_series.value_counts()

# sort in descending order
sorted_counts = genre_counts.sort_values(ascending=False)

# take top 10
top10_counts = sorted_counts.head(9)

# plot as bar chart
fig= plt.subplots(figsize=(8, 6))
plt.bar(top10_counts.index, top10_counts.values)
plt.title('Top 10 Anime Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show(fig)

# %%
genre_counts = pd.Series(genre)
top_genres = genre_counts.sort_values(ascending=False)[:10] # Get top 10 genres
plt.barh(top_genres.index, top_genres.values)
plt.title("Top 10 Genres")
plt.xlabel("Count")
plt.ylabel("Genre")
plt.show()
