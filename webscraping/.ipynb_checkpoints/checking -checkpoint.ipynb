# %%
import pandas as pd

# %%
nameofdataframe = []
for num in range(1,104):
    nameofdataframe.append(f"df{num}")

# %%
for num in range(1,104):
    if num == 37 or num == 56:
        continue
    new_var = nameofdataframe[num] 
    new_var= pd.read_csv(f"data_{num}.csv")

# %%
df
# Out:
#                                               name              Type  \
# 0    C – The Money of Soul and Possibility Control         TV Series
# 1                                         C Danchi   Fall 2022 Anime
# 2                                   C Danchi (Dub)   Fall 2022 Anime
# 3                                                C         TV Series
# 4                       C3 Cube x Cursed x Curious         TV Series
# ..                                             ...               ...
# 131                              Changye Kaita Zhe               ONA
# 132                              Chao Shen Xueyuan               ONA
# 133                     Chao Shen Xueyuan Season 2               ONA
# 134                      Chao Shen Xueyuan Season3               ONA
# 135                  Chao Shen Xueyuan Zhi Hei Jia               ONA
#
#                                           Plot Summary  \
# 0     The Japanese government was rescued from the ...
# ...

# %%
li = []
for i in range(5):
    new_var_name = "var_" + str(i)
#     exec(new_var_name + " = i*2")
#     print(new_var_name, ":", eval(new_var_name))
    new_var_name = f"ishaque{i}"
    li.append(new_var_name)

# %%
# Out:
# ['ishaque0', 'ishaque1', 'ishaque2', 'ishaque3', 'ishaque4']
